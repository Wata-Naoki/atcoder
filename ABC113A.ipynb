# %% [markdown]
# <a href="https://colab.research.google.com/github/Wata-Naoki/atcoder/blob/main/ABC113A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x, y=map(int, input().split())

total=x+(y//2)
print(total)
# Out:
# 81 58
# 110
